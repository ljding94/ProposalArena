# %%
import pymupdf4llm

pdf_path = "data/2023a/statement_of_resch30212.pdf"

md_text = pymupdf4llm.to_markdown(pdf_path)

# Save to the same folder with .md extension
md_path = pdf_path.replace('.pdf', '.md')
with open(md_path, 'w') as f:
    f.write(md_text)

print(f"Markdown saved to {md_path}")
# Out:
# Markdown saved to data/2023a/statement_of_resch30212.md
